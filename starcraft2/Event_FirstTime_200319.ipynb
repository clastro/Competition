# %%
import pandas as pd
import numpy as np

# %%
train=pd.read_csv('train.csv',encoding="utf-8")
test=pd.read_csv('test.csv',encoding="utf-8")

# %%
df = pd.DataFrame(train["game_id"].unique(),columns=["game_id"])

# %%
df_t = pd.DataFrame(test["game_id"].unique(),columns=["game_id"])

# %% [markdown]
# ### Ability만 분류

# %%
df_train = train[train["event"] == "Ability"]
df_test = test[test["event"] == "Ability"]

# %%
# 칼럼 단어만 추출하기
def eliminated_sc(text):
    word = text.split(';')
    col_name = word[0].split(' - ')
    if (len(col_name) >1):
        result = col_name[1]
    else:
        result = 'nothing'
    return result

# %%
df_train.event_contents = df_train.event_contents.apply(lambda x : eliminated_sc(x))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py:5208: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
df_test.event_contents = df_test.event_contents.apply(lambda x : eliminated_sc(x))

# %%
df_train[:30]
# Out:
#      game_id  winner  time  player species    event           event_contents
# 3          0       1  0.02       0       T  Ability                 TrainSCV
# 19         0       1  0.27       0       T  Ability         BuildSupplyDepot
# 27         0       1  0.31       0       T  Ability                     Stop
# 29         0       1  0.33       1       T  Ability                 TrainSCV
# 37         0       1  0.35       0       T  Ability                 TrainSCV
# 43         0       1  0.37       1       T  Ability         BuildSupplyDepot
# 56         0       1  0.40       1       T  Ability            BuildRefinery
# 63         0       1  0.41       1       T  Ability                 TrainSCV
# 87         0       1  1.00       0       T  Ability            BuildBarracks
# 101        0       1  1.03       0       T  Ability                 TrainSCV
# 104        0       1  1.09       0       T  Ability            BuildRefinery
# 124        0       1  1.21       1       T  Ability            BuildBarracks
# 136        0       1  1.25       0       T  Ability                 TrainSCV
# 184        0       1  2.14       0       T  Ability       BuildCommandCenter
# 198        0       1  2.20       0       T  Ability                 TrainSCV
# 223        0       1  2.30       1       T  Ability         BuildSupplyDepot
# 226        0       1  2.32       0       T  Ability         BuildSupplyDepot
# 235        0       1  2.35       1       T  Ability              TrainMarine
# 252        0       1  2.43       0       T  Ability  UpgradeToOrbitalCommand
# 311        0       1  2.52       1       T  Ability             BuildFactory
# 329        0       1  3.00       0       T  Ability              TrainMarine
# 336        0       1  3.06       1       T  Ability  UpgradeToOrbitalCommand
# 367        0       1  3.18       1       T  Ability                   Attack
# 369        0       1  3.19       0       T  Ability             BuildFactory
# 384        0       1  3.22       0       T  Ability                 TrainSCV
# 406        0       1  3.25       1       T  Ability              TrainMarine
# 423        0       1  3.30       0       T  Ability            BuildRefinery
# 442        0       1  3.34       0       T  Ability     BuildBarracksReactor
# 489        0       1  3.46       1       T  Ability            ExtraSupplies
# 491        0       1  3.48       0       T  Ability                 TrainSCV

# %%
importance_building = ['BuildBarracks','BuildExtractor','BuildGateway','BuildRefinery','BuildAssimilator','BuildHatchery',
                      'BuildCommandCenter','BuildNexus','BuildSpawningPool']
attack_building = ['BuildBarracks','BuildGateway','BuildSpawningPool']
gas_building = ['BuildExtractor','BuildRefinery','BuildAssimilator']
multi_building = ['BuildHatchery','BuildCommandCenter','BuildNexus']

# %%
def make_first_column(game_id,player,time,event_contents):
    if event_contents in importance_building:
        
        if event_contents in attack_building:
            event_contents = "BuildAttack"
        elif event_contents in gas_building:
            event_contents = "BuildGas"
        elif event_contents in multi_building:
            event_contents = "BuildMulti"
        
        player_num = "p"+str(player)
        col_name = player_num+"_first_"+str(event_contents)
        if col_name in df.columns:
            if(df.loc[game_id,col_name]>0):
                pass
            else:
                df.loc[game_id,col_name] = time
        else:
            df[col_name] = 0
            df.loc[game_id,col_name] = time

# %%
def make_first_column_test(game_id,player,time,event_contents):
    game_id = game_id - 38872
    if event_contents in importance_building:
        
        if event_contents in attack_building:
            event_contents = "BuildAttack"
        elif event_contents in gas_building:
            event_contents = "BuildGas"
        elif event_contents in multi_building:
            event_contents = "BuildMulti"
        
        player_num = "p"+str(player)
        col_name = player_num+"_first_"+str(event_contents)
        if col_name in df_t.columns:
            if(df_t.loc[game_id,col_name]>0):
                pass
            else:
                df_t.loc[game_id,col_name] = time
        else:
            df_t[col_name] = 0
            df_t.loc[game_id,col_name] = time

# %%
df_train.apply(lambda x : make_first_column(x["game_id"],x["player"],x["time"], x["event_contents"]) , axis = 1 )
# Out:
# 3           None
# 19          None
# 27          None
# 29          None
# 37          None
#             ...
# 67091714    None
# 67091715    None
# 67091726    None
# 67091731    None
# 67091775    None
# Length: 3798390, dtype: object

# %%
df_test.apply(lambda x : make_first_column_test(x["game_id"],x["player"],x["time"], x["event_contents"]) , axis = 1 )
# Out:
# 3           None
# 29          None
# 69          None
# 75          None
# 82          None
#             ...
# 28714832    None
# 28714834    None
# 28714836    None
# 28714837    None
# 28714839    None
# Length: 1631055, dtype: object

# %%
df
# Out:
#        game_id  p1_first_BuildGas  p0_first_BuildAttack  p0_first_BuildGas  \
# 0            0               0.40                  1.00               1.09
# 1            1               1.56                  0.53               1.08
# 2            2               6.19                  0.54               1.08
# 3            3               1.00                  0.56               1.03
# 4            4               5.19                  0.58               1.31
# ...        ...                ...                   ...                ...
# 38867    38867               0.42                  1.06               0.42
# 38868    38868               3.17                  1.04               1.41
# 38869    38869               0.19                  1.58               1.26
# 38870    38870               1.00                  1.51               0.42
# 38871    38871               0.42                  1.46               0.33
#
#        p1_first_BuildAttack  p0_first_BuildMulti  p1_first_BuildMulti
# 0                      1.21                 2.14                 0.00
# 1                      0.58                 7.36                 2.55
# 2                      1.50                 6.45                 3.30
# 3                      0.54                 2.27                 9.26
# 4                      2.13                 2.28                 1.19
# ...                     ...                  ...                  ...
# 38867                  0.00                 2.34                 6.49
# 38868                  3.56                 9.48                 2.33
# 38869                  0.00                 4.06                 3.31
# 38870                  0.53                 4.09                 2.00
# 38871                  1.06                 1.09                 2.28
#
# [38872 rows x 7 columns]

# %%
df.to_csv("ft_build_train.csv",encoding="utf-8",index=False)

# %%
df_t
# Out:
#        game_id  p0_first_BuildGas  p1_first_BuildGas  p1_first_BuildAttack  \
# 0        38872               1.11               1.31                  4.05
# 1        38873               0.00               0.00                  2.01
# 2        38874               0.45               0.41                  0.00
# 3        38875               0.40               0.00                  0.53
# 4        38876               0.26               0.20                  1.27
# ...        ...                ...                ...                   ...
# 16782    55654               1.49               0.40                  1.04
# 16783    55655               0.28               0.40                  1.04
# 16784    55656               1.09               5.05                  4.04
# 16785    55657               0.00               0.46                  1.02
# 16786    55658               0.00               1.05                  1.32
#
#        p1_first_BuildMulti  p0_first_BuildAttack  p0_first_BuildMulti
# 0                     4.41                  4.51                 0.00
# 1                     1.46                  0.00                 1.16
# 2                     0.00                  1.05                 0.00
# 3                     2.02                  1.03                 0.00
# 4                     0.00                  0.00                 0.00
# ...                    ...                   ...                  ...
# 16782                 2.37                  1.50                 1.17
# 16783                 3.30                  1.51                 7.43
# 16784                 0.00                  0.00                 0.00
# 16785                 0.00                  0.57                 0.00
# 16786                 0.00                  1.14                 0.00
#
# [16787 rows x 7 columns]

# %%
df_t.to_csv("ft_build_test.csv",encoding="utf-8",index=False)
