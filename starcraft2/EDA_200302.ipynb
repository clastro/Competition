# %%
import pandas as pd
import numpy as np

# %%
train=pd.read_csv('train.csv',encoding="utf-8-sig")             # feather 파일로 load 시 기존 CSV 파일 보다 2배 빠른 32초를 소요하여 로드 완료
test=pd.read_csv('test.csv',encoding="utf-8-sig")

# %%
submission=pd.read_csv('sample_submission.csv',encoding="utf-8-sig")

# %%
submission
# Out:
#        game_id  winner
# 0        38872       0
# 1        38873       0
# 2        38874       0
# 3        38875       0
# 4        38876       0
# ...        ...     ...
# 16782    55654       0
# 16783    55655       0
# 16784    55656       0
# 16785    55657       0
# 16786    55658       0
#
# [16787 rows x 2 columns]

# %%
train.shape
# Out:
# (67091776, 7)

# %%
train.tail()
# Out:
#           game_id  winner  time  player species            event  \
# 67091771    38871       0  8.51       0       Z           Camera
# 67091772    38871       0  8.52       1       T  GetControlGroup
# 67091773    38871       0  8.52       0       Z           Camera
# 67091774    38871       0  8.52       0       Z           Camera
# 67091775    38871       0  8.52       1       T          Ability
#
#                           event_contents
# 67091771    at (139.578125, 62.58203125)
# 67091772                             NaN
# 67091773   at (122.42578125, 45.4296875)
# 67091774  at (122.42578125, 43.25390625)
# 67091775               (1360) - TrainSCV

# %%
train.head()
# Out:
#    game_id  winner  time  player species      event  \
# 0        0       1  0.00       0       T     Camera
# 1        0       1  0.00       1       T     Camera
# 2        0       1  0.02       0       T  Selection
# 3        0       1  0.02       0       T    Ability
# 4        0       1  0.14       0       T     Camera
#
#                    event_contents
# 0         at (145.25, 21.5078125)
# 1         at (22.75, 147.0078125)
# 2    ['OrbitalCommand [3080001]']
# 3               (1360) - TrainSCV
# 4  at (142.99609375, 24.50390625)

# %%
train[train["game_id"] == 0]
# Out:
#       game_id  winner  time  player species        event  \
# 0           0       1  0.00       0       T       Camera
# 1           0       1  0.00       1       T       Camera
# 2           0       1  0.02       0       T    Selection
# 3           0       1  0.02       0       T      Ability
# 4           0       1  0.14       0       T       Camera
# ...       ...     ...   ...     ...     ...          ...
# 1135        0       1  7.22       0       T       Camera
# 1136        0       1  7.22       0       T       Camera
# 1137        0       1  7.24       1       T      Ability
# 1138        0       1  7.24       0       T  Right Click
# 1139        0       1  7.24       0       T       Camera
#
#                                          event_contents
# 0                               at (145.25, 21.5078125)
# 1                               at (22.75, 147.0078125)
# 2                          ['OrbitalCommand [3080001]']
# ...

# %%
train2 = train[train["game_id"] == 0]

# %%
train2[train2["player"] == 1]
# Out:
#       game_id  winner  time  player species      event  \
# 1           0       1  0.00       1       T     Camera
# 29          0       1  0.33       1       T    Ability
# 30          0       1  0.34       1       T     Camera
# 31          0       1  0.34       1       T     Camera
# 33          0       1  0.34       1       T     Camera
# ...       ...     ...   ...     ...     ...        ...
# 1118        0       1  7.18       1       T  Selection
# 1122        0       1  7.21       1       T  Selection
# 1124        0       1  7.21       1       T     Camera
# 1127        0       1  7.21       1       T     Camera
# 1137        0       1  7.24       1       T    Ability
#
#                                          event_contents
# 1                               at (22.75, 147.0078125)
# 29                                    (1360) - TrainSCV
# 30                                at (22.75, 145.90625)
# 31                             at (22.75, 143.24609375)
# ...

# %%
winer = train2[train2["player"] == 1]
loser = train2[train2["player"] == 0]

# %%
winer[winer["event"]=="Ability"]
# Out:
#       game_id  winner  time  player species    event  \
# 29          0       1  0.33       1       T  Ability
# 43          0       1  0.37       1       T  Ability
# 56          0       1  0.40       1       T  Ability
# 63          0       1  0.41       1       T  Ability
# 124         0       1  1.21       1       T  Ability
# 223         0       1  2.30       1       T  Ability
# 235         0       1  2.35       1       T  Ability
# 311         0       1  2.52       1       T  Ability
# 336         0       1  3.06       1       T  Ability
# 367         0       1  3.18       1       T  Ability
# 406         0       1  3.25       1       T  Ability
# 489         0       1  3.46       1       T  Ability
# 503         0       1  3.49       1       T  Ability
# 537         0       1  3.58       1       T  Ability
# 576         0       1  4.10       1       T  Ability
# 593         0       1  4.15       1       T  Ability
# 663         0       1  4.34       1       T  Ability
# ...

# %%
winer[winer["event"]=="Selection"]
# Out:
#       game_id  winner  time  player species      event  \
# 57          0       1  0.40       1       T  Selection
# 130         0       1  1.23       1       T  Selection
# 141         0       1  1.30       1       T  Selection
# 146         0       1  1.37       1       T  Selection
# 183         0       1  2.12       1       T  Selection
# 210         0       1  2.24       1       T  Selection
# 213         0       1  2.25       1       T  Selection
# 262         0       1  2.44       1       T  Selection
# 312         0       1  2.53       1       T  Selection
# 313         0       1  2.53       1       T  Selection
# 326         0       1  2.59       1       T  Selection
# 343         0       1  3.12       1       T  Selection
# 344         0       1  3.12       1       T  Selection
# 347         0       1  3.15       1       T  Selection
# 387         0       1  3.23       1       T  Selection
# 388         0       1  3.23       1       T  Selection
# ...

# %%
winer[winer["event"]=="AddToControlGroup"]
# Out:
# Empty DataFrame
# Columns: [game_id, winner, time, player, species, event, event_contents]
# Index: []

# %%
loser[loser["event"]=="Ability"]
# Out:
#       game_id  winner  time  player species    event  \
# 3           0       1  0.02       0       T  Ability
# 19          0       1  0.27       0       T  Ability
# 27          0       1  0.31       0       T  Ability
# 37          0       1  0.35       0       T  Ability
# 87          0       1  1.00       0       T  Ability
# 101         0       1  1.03       0       T  Ability
# 104         0       1  1.09       0       T  Ability
# 136         0       1  1.25       0       T  Ability
# 184         0       1  2.14       0       T  Ability
# 198         0       1  2.20       0       T  Ability
# 226         0       1  2.32       0       T  Ability
# 252         0       1  2.43       0       T  Ability
# 329         0       1  3.00       0       T  Ability
# 369         0       1  3.19       0       T  Ability
# 384         0       1  3.22       0       T  Ability
# 423         0       1  3.30       0       T  Ability
# 442         0       1  3.34       0       T  Ability
# ...

# %%
loser[loser["event"]=="Selection"]
# Out:
#       game_id  winner  time  player species      event  \
# 2           0       1  0.02       0       T  Selection
# 28          0       1  0.33       0       T  Selection
# 68          0       1  0.47       0       T  Selection
# 102         0       1  1.06       0       T  Selection
# 103         0       1  1.07       0       T  Selection
# 110         0       1  1.15       0       T  Selection
# 137         0       1  1.27       0       T  Selection
# 145         0       1  1.36       0       T  Selection
# 152         0       1  1.45       0       T  Selection
# 160         0       1  1.47       0       T  Selection
# 171         0       1  1.52       0       T  Selection
# 178         0       1  2.07       0       T  Selection
# 197         0       1  2.19       0       T  Selection
# 214         0       1  2.26       0       T  Selection
# 246         0       1  2.39       0       T  Selection
# 301         0       1  2.50       0       T  Selection
# ...

# %%
winer["event_contents"].describe()
# Out:
# count                        544
# unique                       491
# top       ['Barracks [39C0001]']
# freq                           8
# Name: event_contents, dtype: object

# %%
loser["event_contents"].describe()
# Out:
# count                   563
# unique                  525
# top       (1360) - TrainSCV
# freq                      9
# Name: event_contents, dtype: object

# %%
test.head()
# Out:
#    game_id  time  player species              event             event_contents
# 0    38872  0.00       0       P             Camera     at (22.25, 81.5078125)
# 1    38872  0.00       1       P             Camera  at (120.25, 153.83984375)
# 2    38872  0.01       1       P          Selection        ['Nexus [3100001]']
# 3    38872  0.01       1       P            Ability        (15E0) - TrainProbe
# 4    38872  0.01       1       P  AddToControlGroup                        NaN

# %%
pip install pyarrow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
